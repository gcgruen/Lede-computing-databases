# %%
import pandas as pd

# %%
#df = pd.read_csv('water_data_class.csv')
df = pd.read_csv('water_data_class.csv', encoding='latin-1')

# %%
df
# Out:
#                             country countrycode  population  \
# 0                             Aruba         ABW      103441
# 1                           Andorra         AND       72786
# 2                       Afghanistan         AFG    31627506
# 3                            Angola         AGO    24227524
# 4                           Albania         ALB     2894475
# 5                        Arab World         ARB   385272539
# 6              United Arab Emirates         ARE     9086139
# 7                         Argentina         ARG    42980026
# 8                           Armenia         ARM     3006154
# 9                    American Samoa         ASM       55434
# 10              Antigua and Barbuda         ATG       90900
# 11                        Australia         AUS    23470118
# 12                          Austria         AUT     8545908
# 13                       Azerbaijan         AZE     9535079
# 14                          Burundi         BDI    10816860
# ...
